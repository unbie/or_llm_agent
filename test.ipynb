# %%
import openai
from dotenv import load_dotenv
import os
import re
import subprocess
import sys
import tempfile
import copy
import json
import shutil
import wcwidth
import json
from rich.console import Console
from rich.markdown import Markdown
import io
from contextlib import redirect_stdout
import time
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')  # 非交互式后端
import numpy as np
from utils import (
    is_number_string,
    convert_to_number,
    extract_best_objective,
    extract_and_execute_python_code,
    eval_model_result,

    )
from heuristic_skeleton import HEURISTIC_SKELETON
from heuristic_prompts import HEURISTIC_PLUGIN_TEMPLATE

# Load environment variables from .env file
load_dotenv()

# api_data = dict(
# api_key = 'sk-sbxihlsgrzsjfknusvrxiokzdwxofzbhjdyfznqgqifguclu', #os.getenv("OPENAI_API_KEY")
# base_url = 'https://api.siliconflow.cn/v1' #os.getenv("OPENAI_API_BASE")
# )

# api_data = dict(
# api_key = os.getenv("OPENAI_API_KEY"),
# base_url = os.getenv("OPENAI_API_BASE")
# )

# api_data = dict(
#     api_key = os.getenv("OPENAI_API_KEY")
# )


api_data = dict(
    # 配置 API Key，这里直接填入您的火山引擎 Key，不再从环境变量读取以避免报错
    api_key="3b2262fa-c113-4f64-90db-10ed2659a583",
    # 配置 Base URL，指定为火山引擎的接口地址
    base_url="https://ark.cn-beijing.volces.com/api/v3"
)

# Initialize OpenAI client
# client = openai.OpenAI(
#     api_key=api_data['api_key'],
# )
# 初始化 OpenAI 客户端
client = openai.OpenAI(
    api_key=api_data['api_key'],  # 传入 API Key
    base_url=api_data['base_url']  # 传入 Base URL
)


def get_display_width(text):
    """
    Calculate the display width of a string, accounting for wide characters like Chinese.
    Uses the wcwidth module for accurate width calculation.

    Args:
        text (str): The text to calculate the width for.

    Returns:
        int: The display width of the text.
    """
    return wcwidth.wcswidth(text)


def print_header(text="", add_newline_before=True, add_newline_after=True,
                 border_char="=", side_char="||"):
    """
    Print a header with customizable text in the middle, adjusted to the console window width.
    Properly handles wide characters like Chinese.

    Args:
        text (str): The text to display in the middle of the header.
        add_newline_before (bool): Whether to add a newline before the header.
        add_newline_after (bool): Whether to add a newline after the header.
        border_char (str): Character to use for the top and bottom borders.
        side_char (str): Character to use for the side borders.
    """
    # Add a newline before the header if requested
    if add_newline_before:
        print()

    # Get terminal width
    # try:
    terminal_width = shutil.get_terminal_size().columns
    # except Exception:
    #     # Fallback width if terminal size cannot be determined
    #     terminal_width = 80

    # Ensure minimum width
    terminal_width = max(terminal_width, 40)

    # Calculate side character padding
    side_char_len = len(side_char)

    # Print the top border
    print(border_char * terminal_width)

    # Print the empty line
    print(side_char + " " * (terminal_width - 2 * side_char_len) + side_char)

    # Print the middle line with text
    text_display_width = get_display_width(text)
    available_space = terminal_width - 2 * side_char_len

    if text_display_width <= available_space:
        left_padding = (available_space - text_display_width) // 2
        right_padding = available_space - text_display_width - left_padding
        # print(terminal_width, text_display_width, available_space, left_padding, right_padding)
        print(side_char + " " * left_padding + text + " " * right_padding + side_char)
    else:
        # If text is too long, we need to truncate it
        # This is more complex with wide characters, so we'll do it character by character
        truncated_text = ""
        truncated_width = 0
        for char in text:
            char_width = get_display_width(char)
            if truncated_width + char_width + 3 > available_space:  # +3 for the "..."
                break
            truncated_text += char
            truncated_width += char_width

        truncated_text += "..."
        right_padding = available_space - get_display_width(truncated_text)
        print(side_char + truncated_text + " " * right_padding + side_char)

    # Print the empty line
    print(side_char + " " * (terminal_width - 2 * side_char_len) + side_char)

    # Print the bottom border
    print(border_char * terminal_width)

    # Add a newline after the header if requested
    if add_newline_after:
        print()


def query_llm(messages, model_name="ep-20260106214023-k4p8b", temperature=0):
    """
    调用 LLM 获取响应结果，使用流式输出方式。
    兼容推理模型(DeepSeek R1)的 reasoning_content 输出。
    """
    try:
        # 使用stream=True启用流式输出
        response = client.chat.completions.create(
            model=model_name,
            messages=messages,
            temperature=temperature,
            stream=True
        )

        # 用于累积完整响应
        full_response = ""

        # 用于控制打印格式
        print("[LLM Response] ", end="", flush=True)

        # 逐块处理流式响应
        for chunk in response:
            # 检查是否有 choices
            if not chunk.choices:
                continue

            delta = chunk.choices[0].delta

            # 1. 优先尝试获取 reasoning_content (推理模型的思考过程)
            # 注意：不同版本的 SDK 或 API，字段可能叫 reasoning_content
            reasoning = getattr(delta, 'reasoning_content', None)
            if reasoning:
                # 可以选择用灰色打印思考过程，或者直接打印
                print(reasoning, end="", flush=True)

            # 2. 获取正常的 content (最终回复)
            content = getattr(delta, 'content', None)
            if content:
                print(content, end="", flush=True)
                full_response += content

        # 输出完成后换行
        print()
        return full_response

    except Exception as e:
        print(f"\n[API Exception] {e}")
        # 如果流式失败，返回空字符串以免后续逻辑崩溃
        return ""



def generate_or_code_solver(messages_bak, model_name, data, max_attempts=3):
    messages = copy.deepcopy(messages_bak)
    
    current_project_dir = os.path.dirname(os.path.abspath(__file__)).replace("\\", "/")

    # === 使用更精确的 Prompt ===
    prompt = HEURISTIC_PLUGIN_TEMPLATE  # 使用 heuristic_prompts.py 中定义的模板
    
    messages.append({"role": "user", "content": prompt})
    attempt = 0

    while attempt < max_attempts:
        llm_response = query_llm(messages, model_name)
        
        # === 提取 LLM 生成的代码 ===
        code_match = re.search(r"```python\n(.*?)```", llm_response, re.DOTALL)
        llm_plugin_code = code_match.group(1).strip() if code_match else llm_response
        
        # === 检查是否使用了完整成本计算 ===
        uses_full_cost = "self.solver.calculator.calculate_route_cost" in llm_plugin_code
        uses_simple_dist = "self.dist_matrix[" in llm_plugin_code and "- self.dist_matrix[" in llm_plugin_code
        print(f"\n[成本计算检查] 使用完整成本: {uses_full_cost}, 使用简化距离: {uses_simple_dist}")
        if not uses_full_cost:
            print("⚠️ 警告：LLM生成的代码未使用完整成本计算函数！")
        
        # === 强制提取 HeuristicPlugin 类（防止 LLM 生成其他内容）===
        print("\n[Code Generation] Extracting HeuristicPlugin class...")
        
        # === 统一的 __init__ 方法（与提示模板和执行代码一致）===
        unified_init = (
            "    def __init__(self, *args, **kwargs):\n"
            "        # 支持 HeuristicPlugin(data=data) 调用方式\n"
            "        _data = kwargs.get('data', {})\n"
            "        self.capacity = _data.get('vehicle_capacity', 200)\n"
            "        self.customers = _data.get('customers', [])\n"
            "        self.dist_matrix = None  # 由 Solver 注入\n"
            "        self.solver = None  # 由 Solver 注入\n"
            "        self.customer_lookup = {c['id']: c for c in self.customers}\n"
        )
        
        # 方案 1: 如果 LLM 生成了完整的类定义，只保留方法部分（跳过 __init__）
        if "class HeuristicPlugin:" in llm_plugin_code:
            # 提取类中的方法（去掉类定义行和 __init__）
            lines = llm_plugin_code.split('\n')
            method_lines = []
            in_class = False
            skip_init = False
            init_indent = 0
            
            for line in lines:
                if 'class HeuristicPlugin:' in line:
                    in_class = True
                    continue  # 跳过类定义行
                
                if in_class:
                    # 如果遇到新的类定义（顶层），停止
                    if line.strip() and not line.startswith(' ') and not line.startswith('\t'):
                        if 'class ' in line:
                            break
                    
                    # 跳过 LLM 生成的 __init__ 方法
                    stripped = line.lstrip()
                    if stripped.startswith('def __init__'):
                        skip_init = True
                        init_indent = len(line) - len(stripped)
                        continue
                    if skip_init:
                        # 如果遇到同级别或更高级别的 def，停止跳过
                        if stripped.startswith('def ') and (len(line) - len(stripped)) <= init_indent:
                            skip_init = False
                        else:
                            continue
                    
                    method_lines.append(line)
            
            # 重新构建完整的 Plugin 类（使用统一的 __init__）
            plugin_class_code = "class HeuristicPlugin:\n"
            plugin_class_code += unified_init + "\n"
            plugin_class_code += '\n'.join(method_lines)
            
            print(f"[Code Generation] HeuristicPlugin class reconstructed ({len(plugin_class_code)} chars)")
        else:
            # 方案 2: 如果只生成了方法，手动添加类框架
            plugin_class_code = "class HeuristicPlugin:\n"
            plugin_class_code += unified_init + "\n"
            
            # 给 LLM 生成的方法添加缩进
            indented_methods = '\n'.join('    ' + line if line.strip() else line 
                                         for line in llm_plugin_code.split('\n'))
            plugin_class_code += indented_methods
            
            print(f"[Code Generation] HeuristicPlugin class constructed ({len(plugin_class_code)} chars)")

        # === 自动补全缺失方法（防止 AttributeError）===
        required_destroy_methods = ['random_removal', 'route_removal', 'string_removal']
        required_insert_methods = ['greedy_insert', 'regret_insert']
        
        for method_name in required_destroy_methods:
            if f'def {method_name}' not in plugin_class_code:
                print(f"[Auto-Fix] 补全缺失的破坏算子: {method_name}")
                if method_name == 'route_removal':
                    stub = (
                        "\n    def route_removal(self, solution, ratio):\n"
                        "        \"\"\"路径移除：随机移除整条路径\"\"\"\n"
                        "        if not solution:\n"
                        "            return solution, []\n"
                        "        non_empty = [(i, [n for n in r if n != 0]) for i, r in enumerate(solution) if any(n != 0 for n in r)]\n"
                        "        if not non_empty:\n"
                        "            return solution, []\n"
                        "        idx, customers = random.choice(non_empty)\n"
                        "        new_sol = [r[:] for i, r in enumerate(solution) if i != idx]\n"
                        "        return new_sol, customers\n"
                    )
                elif method_name == 'string_removal':
                    stub = (
                        "\n    def string_removal(self, solution, ratio):\n"
                        "        \"\"\"连续节点移除：委托给random_removal\"\"\"\n"
                        "        return self.random_removal(solution, ratio)\n"
                    )
                else:  # random_removal
                    stub = (
                        "\n    def random_removal(self, solution, ratio):\n"
                        "        \"\"\"随机移除\"\"\"\n"
                        "        all_n = [(ri,pi,n) for ri,r in enumerate(solution) for pi,n in enumerate(r) if n!=0]\n"
                        "        if not all_n: return solution, []\n"
                        "        total = len(all_n)\n"
                        "        k = min(total, max(1, int(ratio) if ratio>1 else math.ceil(total*ratio)))\n"
                        "        sel = random.sample(all_n, k)\n"
                        "        sel.sort(key=lambda x:(x[0],x[1]), reverse=True)\n"
                        "        ns = [r[:] for r in solution]\n"
                        "        rm = []\n"
                        "        for ri,pi,n in sel: del ns[ri][pi]; rm.append(n)\n"
                        "        ns = [r for r in ns if len(r)>2]\n"
                        "        return ns, rm\n"
                    )
                plugin_class_code += stub
        
        for method_name in required_insert_methods:
            if f'def {method_name}' not in plugin_class_code:
                print(f"[Auto-Fix] 补全缺失的修复算子: {method_name}")
                if method_name == 'regret_insert':
                    stub = (
                        "\n    def regret_insert(self, solution, removed_nodes):\n"
                        "        \"\"\"后悔插入：委托给greedy_insert\"\"\"\n"
                        "        return self.greedy_insert(solution, removed_nodes)\n"
                    )
                else:  # greedy_insert - use fallback
                    stub = (
                        "\n    def greedy_insert(self, solution, removed_nodes):\n"
                        "        \"\"\"贪心插入：随机插入\"\"\"\n"
                        "        if not removed_nodes: return solution\n"
                        "        ns = [r[:] for r in solution] if solution else []\n"
                        "        for node in removed_nodes: ns.append([0, node, 0])\n"
                        "        return ns\n"
                    )
                plugin_class_code += stub
        
        # === 拼接最终脚本（关键修改）===
        full_code = (
            "# -*- coding: utf-8 -*-\n"
            "import math, json, random, copy, sys, traceback\n"
            f"sys.path.append('{current_project_dir}')\n"
            "from utils import FreshnessAndPenaltyCalculator\n\n"
            f"data = {json.dumps(data)}\n\n"
            # === 第一部分：Skeleton（包含 HeuristicSolver）===
            f"{HEURISTIC_SKELETON}\n\n"
            # === 第二部分：LLM 生成的 HeuristicPlugin ===
            f"{plugin_class_code}\n\n"
            # === 第三部分：执行代码 ===
            "if __name__ == '__main__':\n"
            "    try:\n"
            "        plugin = HeuristicPlugin(data=data)\n"
            "        print('[Initialization] Plugin initialized')\n"
            "        solver = HeuristicSolver(data, plugin)\n"
            "        print('[Initialization] Solver initialized')\n"
            "        best_sol, best_cost = solver.solve_multi_run(max_iters=600, num_runs=3)\n"
            "        print(f'BEST_COST: {best_cost}')\n"
            "        print(f'BEST_SOLUTION: {best_sol}')\n"
            "    except Exception as e:\n"
            "        print(f'[Runtime Exception] {e}')\n"
            "        traceback.print_exc(file=sys.stdout)\n"
        )

        # === 验证代码结构 ===
        solver_count = full_code.count('class HeuristicSolver')
        plugin_count = full_code.count('class HeuristicPlugin')
        init_debug = '[初始化]' in full_code
        
        print(f"[Code Validation] Solver classes: {solver_count}, Plugin classes: {plugin_count}")
        
        if solver_count != 1 or plugin_count != 1:
            print(f"[Warning] Unexpected class count - Solver={solver_count}, Plugin={plugin_count}")
        
     
        # === 执行代码 ===
        success, result_msg = extract_and_execute_python_code(f"```python\n{full_code}\n```")

        if success and "BEST_COST:" in result_msg:
            print("\n[Solver Status] Algorithm execution completed")
            return True, result_msg, messages_bak

        print(f"\n[Attempt {attempt+1}/{max_attempts}] Code refinement needed")
        print(f"[Debug Info]\n{result_msg}\n")
        messages.append({"role": "assistant", "content": llm_response})
        messages.append({
            "role": "user", 
            "content": f"Code execution encountered issues. Please refine the implementation.\n\nDebug information:\n{result_msg}\n\n"
            f"【重要】你的类必须恰好包含以下5个方法：\n"
            f"  1. random_removal(self, solution, ratio)\n"
            f"  2. route_removal(self, solution, ratio)\n"
            f"  3. string_removal(self, solution, ratio)\n"
            f"  4. greedy_insert(self, solution, removed_nodes)\n"
            f"  5. regret_insert(self, solution, removed_nodes)\n"
            f"只实现这5个，不多不少。regret_insert 中只需比较每条路径的最佳插入位置即可。"
        })
        attempt += 1

    return False, None, messages_bak

def extract_solution_from_output(output):
    """从求解输出中提取路线信息"""
    solution = []
    
    print("[调试] 开始提取路线信息...")
    
    # 尝试多种格式提取路线
    # 格式1: Route 1: [0, 1, 2, 0]
    route_pattern1 = r'Route \d+: \[(.*?)\]'
    matches = re.findall(route_pattern1, output, re.IGNORECASE)
    
    print(f"[调试] 格式1匹配到 {len(matches)} 条路线")
    
    if matches:
        for i, match in enumerate(matches):
            nodes_str = match.strip()
            if nodes_str:
                try:
                    # 更宽松的数字提取
                    nodes = [int(x.strip()) for x in nodes_str.split(',') if x.strip().lstrip('-').isdigit()]
                    if nodes:
                        solution.append(nodes)
                        print(f"[调试] 路线 {i+1}: {nodes[:5]}{'...' if len(nodes) > 5 else ''}")
                except Exception as e:
                    print(f"[调试] 解析路线 {i+1} 失败: {e}")
    
    # 格式2: BEST_SOLUTION: [[0,1,2,0], [0,3,4,0]]
    if not solution:
        print("[调试] 尝试格式2...")
        solution_pattern = r'BEST_SOLUTION:\s*(\[\[.*?\]\])'
        match = re.search(solution_pattern, output, re.DOTALL)
        if match:
            try:
                import ast
                solution = ast.literal_eval(match.group(1))
                print(f"[调试] 格式2提取到 {len(solution)} 条路线")
            except Exception as e:
                print(f"[调试] 格式2解析失败: {e}")
    
    # 如果还是没有，尝试更宽松的匹配
    if not solution:
        print("[调试] 尝试宽松匹配...")
        # 查找任何包含节点列表的行
        route_lines = re.findall(r'路线\s*\d+[：:]\s*\[(.*?)\]', output, re.IGNORECASE)
        if route_lines:
            print(f"[调试] 宽松匹配找到 {len(route_lines)} 条路线")
            for line in route_lines:
                try:
                    nodes = [int(x.strip()) for x in line.split(',') if x.strip().lstrip('-').isdigit()]
                    if nodes:
                        solution.append(nodes)
                except:
                    pass
    
    print(f"[调试] 最终提取到 {len(solution)} 条路线")
    return solution

def extract_iteration_history(output):
    """从输出中提取迭代历史 - 只提取最后一次运行的数据"""
    iterations = []
    cost_history = []
    best_history = []
    
    # 查找迭代信息，格式如: "Iter 10: Current=1234.56, Best=1200.00"
    iter_pattern = r'Iter\s+(\d+):\s+Current=([\d.]+),\s+Best=([\d.]+)'
    matches = re.findall(iter_pattern, output)
    
    if not matches:
        return iterations, cost_history, best_history
    
    # 检测运行边界：当迭代次数重置（从大到小）时，说明开始新一轮
    all_runs = []
    current_run = []
    
    for match in matches:
        iteration, current_cost, best_cost = match
        iter_num = int(iteration)
        
        # 如果迭代次数变小，说明开始了新一轮
        if current_run and iter_num <= current_run[-1][0]:
            all_runs.append(current_run)
            current_run = []
        
        current_run.append((iter_num, float(current_cost), float(best_cost)))
    
    # 添加最后一轮
    if current_run:
        all_runs.append(current_run)
    
    # 只返回最后一次运行的数据（通常是最优的）
    if all_runs:
        last_run = all_runs[-1]
        iterations = [item[0] for item in last_run]
        cost_history = [item[1] for item in last_run]
        best_history = [item[2] for item in last_run]
    
    return iterations, cost_history, best_history

def visualize_results(dataset, solution, best_cost, output):
    """生成学术风格的可视化图表"""
    # === 学术风格全局设置 ===
    plt.rcParams.update({
        'font.family': 'serif',
        'font.serif': ['Times New Roman', 'SimSun'],  # 英文用 TNR，中文回退宋体
        'mathtext.fontset': 'stix',
        'axes.unicode_minus': False,
        'axes.linewidth': 0.8,
        'axes.labelsize': 11,
        'axes.titlesize': 12,
        'xtick.labelsize': 9,
        'ytick.labelsize': 9,
        'legend.fontsize': 9,
        'figure.dpi': 150,
        'savefig.dpi': 600,
        'lines.linewidth': 1.2,
        'grid.alpha': 0.3,
        'grid.linewidth': 0.5,
        'grid.linestyle': '--',
    })
    
    fig, axes = plt.subplots(1, 3, figsize=(16, 4.8))
    
    # ═══════════════════════════════════════════════════
    # (a) Convergence Curve
    # ═══════════════════════════════════════════════════
    ax1 = axes[0]
    iterations, cost_history, best_history = extract_iteration_history(output)
    
    if cost_history and best_history and iterations:
        # 移动平均平滑
        window_size = max(5, len(cost_history) // 10)
        
        def moving_average(data, window):
            if len(data) < window:
                return data
            smoothed = []
            for i in range(len(data)):
                start = max(0, i - window // 2)
                end = min(len(data), i + window // 2 + 1)
                smoothed.append(sum(data[start:end]) / (end - start))
            return smoothed
        
        cost_smooth = moving_average(cost_history, window_size)
        
        # 学术配色：灰 + 蓝 + 红
        ax1.plot(iterations, cost_history, color='#B0B0B0', linewidth=0.6, alpha=0.4, label='Current cost (raw)')
        ax1.plot(iterations, cost_smooth, color='#2166AC', linewidth=1.4, label='Current cost (smoothed)')
        ax1.plot(iterations, best_history, color='#B2182B', linewidth=1.6, linestyle='-', label='Best cost')
        
        # y 轴范围
        min_cost = min(min(best_history), min(cost_smooth))
        max_cost = max(max(best_history), max(cost_smooth))
        y_range = max_cost - min_cost
        if y_range > 0:
            ax1.set_ylim(min_cost - y_range * 0.05, max_cost + y_range * 0.08)
        
        # 标注最优解（简洁学术箭头）
        min_idx = best_history.index(min(best_history))
        ax1.annotate(
            f'{best_history[min_idx]:.2f}',
            xy=(iterations[min_idx], best_history[min_idx]),
            xytext=(30, 20), textcoords='offset points',
            fontsize=9, color='#B2182B',
            arrowprops=dict(arrowstyle='->', color='#B2182B', lw=1.0),
            bbox=dict(boxstyle='round,pad=0.3', facecolor='white', edgecolor='#B2182B', linewidth=0.8, alpha=0.9)
        )
        
        ax1.set_xlabel('Iteration')
        ax1.set_ylabel('Objective Value')
        ax1.set_title('(a) ALNS Convergence Curve', fontweight='bold')
        ax1.legend(loc='upper right', frameon=True, edgecolor='gray', fancybox=False, framealpha=0.9)
        ax1.grid(True)
        ax1.tick_params(direction='in', top=True, right=True)
    else:
        ax1.text(0.5, 0.5, 'No iteration data', ha='center', va='center', transform=ax1.transAxes, fontsize=11)
        ax1.set_title('(a) ALNS Convergence Curve', fontweight='bold')
    
    # ═══════════════════════════════════════════════════
    # (b) Vehicle Routing Map
    # ═══════════════════════════════════════════════════
    ax2 = axes[1]
    customers = dataset['customers']
    depot = customers[0]
    depot_x, depot_y = depot['x'], depot['y']
    
    # 学术配色方案（区分度高、打印友好）
    academic_colors = [
        '#1f77b4', '#d62728', '#2ca02c', '#ff7f0e', '#9467bd',
        '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf',
        '#393b79', '#637939', '#8c6d31', '#843c39', '#7b4173',
        '#5254a3', '#6b6ecf', '#9c9ede', '#bd9e39', '#ad494a',
    ]
    
    # 绘制路线
    if solution and len(solution) > 0:
        for idx, route in enumerate(solution):
            try:
                if not route or len(route) == 0:
                    continue
                complete_route = []
                if route[0] != 0:
                    complete_route.append(0)
                complete_route.extend(route)
                if route[-1] != 0:
                    complete_route.append(0)
                
                route_x = [customers[n]['x'] for n in complete_route if n < len(customers)]
                route_y = [customers[n]['y'] for n in complete_route if n < len(customers)]
                
                if len(route_x) >= 2:
                    color = academic_colors[idx % len(academic_colors)]
                    ax2.plot(route_x, route_y, '-', color=color, linewidth=1.0, alpha=0.7, zorder=2)
                    # 客户点
                    if len(route_x) > 2:
                        ax2.scatter(route_x[1:-1], route_y[1:-1], c=color, s=20, alpha=0.85,
                                   zorder=4, edgecolors='black', linewidths=0.3)
            except Exception:
                continue
    
    # 仓库（黑色方块，学术常见标记）
    ax2.plot(depot_x, depot_y, 's', color='black', markersize=10, zorder=6, label='Depot')
    
    # 所有客户点（灰色底层，在有路线时不重复绘制）
    if not solution or len(solution) == 0:
        customer_coords = [(c['x'], c['y']) for c in customers[1:]]
        if customer_coords:
            cx, cy = zip(*customer_coords)
            ax2.scatter(cx, cy, c='#666666', s=15, alpha=0.5, zorder=3, label='Customer')
    
    ax2.set_xlabel('$x$ coordinate')
    ax2.set_ylabel('$y$ coordinate')
    route_count = len(solution) if solution else 0
    ax2.set_title(f'(b) Vehicle Routes ($K$={route_count})', fontweight='bold')
    ax2.grid(True)
    ax2.set_aspect('equal')
    ax2.tick_params(direction='in', top=True, right=True)
    # 简化图例：只显示仓库标记
    ax2.legend(loc='upper right', frameon=True, edgecolor='gray', fancybox=False, framealpha=0.9, markerscale=0.8)
    
    # ═══════════════════════════════════════════════════
    # (c) Multi-run Cost Comparison
    # ═══════════════════════════════════════════════════
    ax3 = axes[2]
    
    multi_run_pattern = r'各次成本: \[(.*?)\]'
    multi_run_match = re.search(multi_run_pattern, output)
    
    if multi_run_match:
        costs_str = multi_run_match.group(1)
        costs = [float(c.strip().strip("'\"")) for c in costs_str.split(',')]
        
        runs = list(range(1, len(costs) + 1))
        min_cost_val = min(costs)
        avg_cost_val = sum(costs) / len(costs)
        
        # 学术柱状图：灰色 + 最优高亮
        bar_colors = ['#B2182B' if c == min_cost_val else '#4393C3' for c in costs]
        bars = ax3.bar(runs, costs, color=bar_colors, alpha=0.85, edgecolor='black', linewidth=0.6, width=0.6)
        
        # 参考线
        ax3.axhline(y=min_cost_val, color='#B2182B', linestyle='--', linewidth=0.8, alpha=0.7,
                    label=f'Best = {min_cost_val:.2f}')
        ax3.axhline(y=avg_cost_val, color='#2166AC', linestyle=':', linewidth=0.8, alpha=0.7,
                    label=f'Mean = {avg_cost_val:.2f}')
        
        # 数值标注
        for bar, cost in zip(bars, costs):
            ax3.text(bar.get_x() + bar.get_width() / 2., bar.get_height(),
                    f'{cost:.1f}', ha='center', va='bottom', fontsize=8)
        
        # y 轴截断显示（避免从 0 开始导致差异不明显）
        cost_range = max(costs) - min(costs)
        if cost_range > 0:
            y_bottom = min(costs) - cost_range * 1.5
            y_top = max(costs) + cost_range * 1.0
            ax3.set_ylim(y_bottom, y_top)
        
        ax3.set_xlabel('Run')
        ax3.set_ylabel('Objective Value')
        ax3.set_xticks(runs)
        ax3.set_title('(c) Multi-run Comparison', fontweight='bold')
        ax3.legend(loc='upper right', frameon=True, edgecolor='gray', fancybox=False, framealpha=0.9)
        ax3.grid(True, axis='y')
        ax3.tick_params(direction='in', top=True, right=True)
    else:
        ax3.text(0.5, 0.5, 'No multi-run data', ha='center', va='center', transform=ax3.transAxes, fontsize=11)
        ax3.set_title('(c) Multi-run Comparison', fontweight='bold')
    
    plt.tight_layout(w_pad=2.5)
    
    # 保存
    import os
    project_dir = os.path.dirname(os.path.abspath(__file__))
    output_path = os.path.join(project_dir, 'vrp_result.png')
    plt.savefig(output_path, dpi=600, bbox_inches='tight', facecolor='white', pad_inches=0.15)
    # 同时保存 PDF（学术投稿用矢量图）
    pdf_path = os.path.join(project_dir, 'vrp_result.pdf')
    plt.savefig(pdf_path, bbox_inches='tight', facecolor='white', pad_inches=0.15)
    plt.close()
    print(f"[可视化] 图表已保存到: {output_path}")
    print(f"[可视化] 矢量图已保存到: {pdf_path}")

def extract_operator_stats(output):
    """从输出中提取算子统计信息"""
    stats = {}
    
    # 查找算子统计，格式如: "random_removal: 100 uses, 5 success (5.0%)"
    pattern = r'(\w+):\s+(\d+)\s+uses?,\s+(\d+)\s+success.*?\((\d+\.?\d*)%\)'
    matches = re.findall(pattern, output)
    
    for match in matches:
        op_name, uses, successes, rate = match
        if int(uses) > 0:  # 只显示使用过的算子
            stats[op_name] = {
                'uses': int(uses),
                'successes': int(successes),
                'rate': float(rate)
            }
    
    return stats

def load_solomon_data(file_path):
    data = {}
    customers = []
    vehicle_capacity = None
    with open(file_path, 'r') as f:
        lines = f.readlines()
    for idx, line in enumerate(lines):
        line = line.strip()
        if line == "" or line.startswith("C") or line.startswith("VEHICLE") or line.startswith("NUMBER") or line.startswith("CUSTOMER"):
            continue
        parts = line.split()
        if len(parts) == 2 and vehicle_capacity is None:
            vehicle_capacity = int(parts[1])
            break
    if vehicle_capacity is None:
        vehicle_capacity = 200
    for line in lines:
        line = line.strip()
        if line == "" or line.startswith("C") or line.startswith("VEHICLE") or line.startswith("NUMBER") or line.startswith("CUSTOMER") or line.startswith("CUST"):
            continue
        parts = line.split()
        if parts[0].isdigit() and len(parts) >= 7:
            cust_id = int(parts[0])
            x = float(parts[1])
            y = float(parts[2])
            demand = int(parts[3])
            ready_time = float(parts[4])
            due_date = float(parts[5])
            service_time = float(parts[6])
            customers.append({
                "id": cust_id, "demand": demand, "x": x, "y": y,
                "ready_time": ready_time, "due_date": due_date, "service_time": service_time
            })
    data["vehicle_capacity"] = vehicle_capacity
    data["customers"] = customers
    return data



if __name__ == "__main__":
    import sys
    import os
    import io
    sys.path.append(os.path.dirname(os.path.abspath(__file__)))

    console = Console()
    model_name = 'ep-20260106214023-k4p8b'
    messages_bak = []

    solomon_file = r"D:\pythonProject\or_llm_agent\data\1 Solomon Benchmark\c1\c105.txt"

    dataset = load_solomon_data(solomon_file)
    # Patch time windows for depot
    if dataset['customers']:
        depot = dataset['customers'][0]
        for cust in dataset['customers']:
            cust['E_i'] = max(0, cust['ready_time']) if cust['id'] != 0 else 0
            cust['L_i'] = min(depot['due_date'], cust['due_date']) if cust['id'] != 0 else depot['due_date']

    print_header("ALNS-based VRP Solver with LLM-generated Heuristics")
    print(f"Dataset: Solomon C101")
    print(f"Model: DeepSeek R1")
    print(f"Algorithm: Adaptive Large Neighborhood Search\n")
    
    is_solve_success, output, _ = generate_or_code_solver(
        messages_bak, model_name, dataset, max_attempts=5
    )

    if is_solve_success:
        print("\n" + "="*80)
        print("SOLUTION SUMMARY")
        print("="*80)
        
        # Extract and display key metrics
        cost_match = re.search(r'BEST_COST:\s*([\d.]+)', output)
        best_cost = None
        if cost_match:
            best_cost = float(cost_match.group(1))
            print(f"\nObjective Value: {best_cost:.2f}")
        
        route_matches = re.findall(r'Route \d+', output)
        if route_matches:
            print(f"Number of Routes: {len(route_matches)}")
        
        # Extract solution for visualization
        solution = extract_solution_from_output(output)
        
        print(f"\n[调试] 提取到的路线数量: {len(solution) if solution else 0}")
        if solution and len(solution) > 0:
            print(f"[调试] 第一条路线示例: {solution[0][:10]}{'...' if len(solution[0]) > 10 else ''}")
        
        # Visualize results - 即使没有solution也尝试生成图表
        if best_cost:
            print("[可视化] 正在生成图表...")
            try:
                visualize_results(dataset, solution, best_cost, output)
            except Exception as e:
                print(f"[可视化错误] {e}")
                import traceback
                traceback.print_exc()
        
        print("\n" + "="*80)
        print("DETAILED OUTPUT")
        print("="*80)
        print(output)
    else:
        print("\n" + "="*80)
        print("EXECUTION TERMINATED")
        print("="*80)
        print("\nNote: Maximum iteration limit reached.")
        print("The algorithm has completed all attempted refinements.")
# Out:
# ================================================================================
# ||                                                                            ||
# ||            ALNS-based VRP Solver with LLM-generated Heuristics             ||
# ||                                                                            ||
# ================================================================================
#
# Dataset: Solomon C101
# Model: DeepSeek R1
# Algorithm: Adaptive Large Neighborhood Search
#
# [LLM Response] 我们按照要求实现5个方法：3个破坏算子（random_removal, route_removal, string_removal）和2个修复算子（greedy_insert, regret_insert）
#  注意：必须使用完整成本计算（在修复算子中），禁止使用简化距离增量计算。
#  注意：破坏算子中要处理ratio（可能是小数或整数）并计算移除数量，注意边界条件（空列表、降序移除等）
#  注意：修复算子中要检查容量约束，并使用完整成本计算（包括新路径的固定成本）
#  我们将严格按照上述要求编写代码。
# 根据您的要求，我实现了完整的启发式算子类，包含5个必需的方法。以下是完整代码：
#
# ```python
# import random
# import math
#
# class HeuristicPlugin:
#     def __init__(self, *args, **kwargs):
#         _data = kwargs.get('data', {})
#         self.capacity = _data.get('vehicle_capacity', 200)
#         self.customers = _data.get('customers', [])
#         self.dist_matrix = None
#         self.solver = None
#         self.customer_lookup = {c['id']: c for c in self.customers}
#
#     def random_removal(self, solution, ratio):
#         all_nodes = []
#         for route_idx, route in enumerate(solution):
#             for pos_idx, node in enumerate(route):
#                 if node != 0:
#                     all_nodes.append((route_idx, pos_idx, node))
#
#         if not all_nodes:
#             return solution, []
#
#         total_customers = len(all_nodes)
#         if ratio <= 1.0:
#             n = max(1, math.ceil(total_customers * ratio))
#         else:
#             n = int(ratio)
#         n = min(n, total_customers)
#
#         selected = random.sample(all_nodes, n)
#         selected.sort(key=lambda x: (x[0], x[1]), reverse=True)
#
#         new_solution = [route[:] for route in solution]
#         removed_nodes = []
#         for route_idx, pos_idx, node in selected:
#             del new_solution[route_idx][pos_idx]
#             removed_nodes.append(node)
#
#         new_solution = [route for route in new_solution if len(route) > 2]
#         return new_solution, removed_nodes
#
#     def route_removal(self, solution, ratio):
#         routes_with_customers = []
#         for route_idx, route in enumerate(solution):
#             customers = [node for node in route if node != 0]
#             if customers:
#                 routes_with_customers.append((route_idx, customers))
#
#         if not routes_with_customers:
#             return solution, []
#
#         total_customers = sum(len(c) for _, c in routes_with_customers)
#         if ratio <= 1.0:
#             target = max(1, math.ceil(total_customers * ratio))
#         else:
#             target = int(ratio)
#
#         random.shuffle(routes_with_customers)
#         removed_nodes = []
#         routes_to_remove = []
#
#         for route_idx, customers in routes_with_customers:
#             removed_nodes.extend(customers)
#             routes_to_remove.append(route_idx)
#             if len(removed_nodes) >= target:
#                 break
#
#         routes_to_remove.sort(reverse=True)
#         new_solution = [route[:] for route in solution]
#         for route_idx in routes_to_remove:
#             del new_solution[route_idx]
#
#         return new_solution, removed_nodes[:target]
#
#     def string_removal(self, solution, ratio):
#         all_nodes = [node for route in solution for node in route if node != 0]
#         if not all_nodes:
#             return solution, []
#
#         total_customers = len(all_nodes)
#         if ratio <= 1.0:
#             n = max(1, math.ceil(total_customers * ratio))
#         else:
#             n = int(ratio)
#         n = min(n, total_customers)
#
#         removed_nodes = []
#         new_solution = [route[:] for route in solution]
#
#         while len(removed_nodes) < n and any(len(r) > 2 for r in new_solution):
#             valid_routes = [(i, r) for i, r in enumerate(new_solution) if len(r) > 2]
#             if not valid_routes:
#                 break
#
#             route_idx, route = random.choice(valid_routes)
#             start_pos = random.randint(1, len(route) - 2)
#             string_len = min(random.randint(1, 3), len(route) - start_pos - 1, n - len(removed_nodes))
#
#             for _ in range(string_len):
#                 if start_pos < len(new_solution[route_idx]) - 1:
#                     node = new_solution[route_idx][start_pos]
#                     if node != 0:
#                         removed_nodes.append(node)
#                         del new_solution[route_idx][start_pos]
#
#         new_solution = [route for route in new_solution if len(route) > 2]
#         return new_solution, removed_nodes
#
#     def greedy_insert(self, solution, removed_nodes):
#         if not removed_nodes:
#             return solution
#         if not solution:
#             return [[0, node, 0] for node in removed_nodes]
#
#         new_solution = [route[:] for route in solution]
#
#         for node in removed_nodes:
#             node_demand = self.customer_lookup[node]['demand']
#             best_cost_increase = float('inf')
#             best_route_idx = None
#             best_position = None
#
#             for route_idx, route in enumerate(new_solution):
#                 route_demand = sum(self.customer_lookup[n]['demand'] for n in route if n != 0)
#                 if route_demand + node_demand > self.capacity:
#                     continue
#
#                 route_before = [self.solver.id_to_customer[n] for n in route]
#                 cost_before = self.solver.calculator.calculate_route_cost(
#                     route_before, self.dist_matrix
#                 )['variable_cost']
#
#                 for pos in range(1, len(route)):
#                     route_after = route[:pos] + [node] + route[pos:]
#                     route_after_nodes = [self.solver.id_to_customer[n] for n in route_after]
#                     cost_after = self.solver.calculator.calculate_route_cost(
#                         route_after_nodes, self.dist_matrix
#                     )['variable_cost']
#
#                     cost_inc = cost_after - cost_before
#
#                     if cost_inc < best_cost_increase:
#                         best_cost_increase = cost_inc
#                         best_route_idx = route_idx
#                         best_position = pos
#
#             new_route = [0, node, 0]
#             route_nodes_new = [self.solver.id_to_customer[n] for n in new_route]
#             new_route_cost = self.solver.calculator.calculate_route_cost(
#                 route_nodes_new, self.dist_matrix
#             )['variable_cost']
#             new_route_cost += self.solver.calculator.f
#
#             if best_route_idx is not None and best_cost_increase <= new_route_cost:
#                 new_solution[best_route_idx].insert(best_position, node)
#             else:
#                 new_solution.append([0, node, 0])
#
#         return new_solution
#
#     def regret_insert(self, solution, removed_nodes):
#         if not removed_nodes:
#             return solution
#         if not solution:
#             return [[0, node, 0] for node in removed_nodes]
#
#         new_solution = [route[:] for route in solution]
#         remaining = list(removed_nodes)
#
#         while remaining:
#             best_regret = -float('inf')
#             best_node = None
#             best_route_idx = None
#             best_position = None
#
#             for node in remaining:
#                 node_demand = self.customer_lookup[node]['demand']
#                 route_best_costs = []
#
#                 for route_idx, route in enumerate(new_solution):
#                     route_demand = sum(self.customer_lookup[n]['demand'] for n in route if n != 0)
#                     if route_demand + node_demand > self.capacity:
#                         continue
#
#                     route_before = [self.solver.id_to_customer[n] for n in route]
#                     cost_before = self.solver.calculator.calculate_route_cost(
#                         route_before, self.dist_matrix
#                     )['variable_cost']
#
#                     best_inc_this_route = float('inf')
#                     best_pos_this_route = 1
#                     for pos in range(1, len(route)):
#                         route_after = route[:pos] + [node] + route[pos:]
#                         route_after_nodes = [self.solver.id_to_customer[n] for n in route_after]
#                         cost_after = self.solver.calculator.calculate_route_cost(
#                             route_after_nodes, self.dist_matrix
#                         )['variable_cost']
#                         cost_inc = cost_after - cost_before
#                         if cost_inc < best_inc_this_route:
#                             best_inc_this_route = cost_inc
#                             best_pos_this_route = pos
#
#                     route_best_costs.append((best_inc_this_route, route_idx, best_pos_this_route))
#
#                 new_route = [0, node, 0]
#                 route_nodes_new = [self.solver.id_to_customer[n] for n in new_route]
#                 new_route_cost = self.solver.calculator.calculate_route_cost(
#                     route_nodes_new, self.dist_matrix
#                 )['variable_cost']
#                 new_route_cost += self.solver.calculator.f
#                 route_best_costs.append((new_route_cost, None, None))
#
#                 route_best_costs.sort(key=lambda x: x[0])
#
#                 if len(route_best_costs) >= 2:
#                     regret = route_best_costs[1][0] - route_best_costs[0][0]
#                 else:
#                     regret = 0
#
#                 if regret > best_regret:
#                     best_regret = regret
#                     best_node = node
#                     best_route_idx = route_best_costs[0][1]
#                     best_position = route_best_costs[0][2]
#
#             if best_node is None:
#                 for node in remaining:
#                     new_solution.append([0, node, 0])
#                 break
#
#             if best_route_idx is not None:
#                 new_solution[best_route_idx].insert(best_position, best_node)
#             else:
#                 new_solution.append([0, best_node, 0])
#
#             remaining.remove(best_node)
#
#         return new_solution
# ```
#
# ### 关键实现说明：
#
# 1. **破坏算子**：
#    - `random_removal`: 随机移除ratio比例的客户节点（降序排序避免索引错误）
#    - `route_removal`: 移除整条路径（按路径移除，更激进）
#    - `string_removal`: 移除连续2-3个节点（保持路径结构）
#
# 2. **修复算子**：
#    - `greedy_insert`: 将节点插入到成本增量最小的位置
#    - `regret_insert`: 优先插入后悔值最大的节点（错过机会成本高的节点）
#
# 3. **完整成本计算**：
#    - 严格使用`solver.calculator.calculate_route_cost()`计算完整成本
#    - 新路径添加固定成本：`new_route_cost += self.solver.calculator.f`
#    - 成本增量计算：`cost_inc = cost_after - cost_before`
#
# 4. **边界处理**：
#    - 所有方法都处理空输入情况
#    - 移除数量计算：`n = min(n, total_customers)`
#    - 容量约束检查：`route_demand + node_demand <= capacity`
#
# 5. **性能优化**：
#    - 后悔插入中只计算每条路径的最佳位置
#    - 降序排序避免索引错误
#    - 及时清理空路径
#
# 这个实现完全遵循了您的要求，包含5个必需的方法，使用完整成本计算，并处理了所有边界条件。
#
# [成本计算检查] 使用完整成本: True, 使用简化距离: False
#
# [Code Generation] Extracting HeuristicPlugin class...
# [Code Generation] HeuristicPlugin class reconstructed (9836 chars)
# [Code Validation] Solver classes: 1, Plugin classes: 1
# Found Python code block, starting execution...
#
#   [求解进度] [Initialization] Plugin initialized (0s)
#
#   [求解进度] [Initialization] Solver initialized (0s)
#
#   [求解进度] ############################################################ (0s)
#
#   [求解进度] # 第 1/3 次运行 (0s)
#
#   [求解进度] ############################################################ (0s)
#
#   [求解进度] [初始化] 开始生成初始解... (迭代次数: 600) (0s)
#
#   [求解进度] [选择最优初始解] 成本: 87606.91 (0s)
#
#   [求解进度] [参数] 初始温度: 8760.69, 冷却系数: 0.993501, 迭代次数: 600 (0s)
#
#   [求解进度] [迭代   3] ✓ 新最优解! 成本: 80898.69, 路径数: 24 (1s)
#
#   [求解进度] [迭代   4] ✓ 新最优解! 成本: 70269.36, 路径数: 25 (1s)
#   [求解进度] [██████░░░░░░░░░░░░░░]  33.3% | 轮次1/3 迭代600/600 | 最优: 42412.45 | 已用: 2m8s | 剩余: 4m16s
#   [求解进度] 【最终结果】最优成本: 42412.45 (2m8s)
#
#   [求解进度] 【最终结果】路径数量: 34 (2m8s)
#
#   [求解进度] 【最终结果】改进次数: 31 (2m8s)
#
#   [求解进度] 【最终结果】最后改进: 第 538 次迭代 (2m8s)
#
#   [求解进度] *** 发现更优解: 42412.45 *** (2m8s)
#
#   [求解进度] # 第 2/3 次运行 (2m8s)
#
#   [求解进度] ############################################################ (2m8s)
#
#   [求解进度] [初始化] 开始生成初始解... (迭代次数: 600) (2m8s)
#
#   [求解进度] [选择最优初始解] 成本: 87606.91 (2m8s)
#
#   [求解进度] [参数] 初始温度: 8760.69, 冷却系数: 0.993501, 迭代次数: 600 (2m8s)
#
#   [求解进度] [迭代   0] ✓ 新最优解! 成本: 74986.80, 路径数: 23 (2m8s)
#
#   [求解进度] [迭代   1] ✓ 新最优解! 成本: 65360.22, 路径数: 25 (2m8s)
#
#   [求解进度] [迭代   2] ✓ 新最优解! 成本: 61095.51, 路径数: 27 (2m9s)
#
#   [求解进度] [迭代   3] ✓ 新最优解! 成本: 58070.00, 路径数: 29 (2m9s)
#
#   [求解进度] [迭代   4] ✓ 新最优解! 成本: 51648.99, 路径数: 31 (2m10s)
#   [求解进度] [█████████████░░░░░░░]  66.7% | 轮次2/3 迭代600/600 | 最优: 42764.11 | 已用: 4m14s | 剩余: 2m7s
#   [求解进度] 【最终结果】最优成本: 42764.11 (4m14s)
#
#   [求解进度] 【最终结果】路径数量: 33 (4m14s)
#
#   [求解进度] 【最终结果】改进次数: 39 (4m14s)
#
#   [求解进度] 【最终结果】最后改进: 第 576 次迭代 (4m14s)
#
#   [求解进度] # 第 3/3 次运行 (4m14s)
#
#   [求解进度] ############################################################ (4m14s)
#
#   [求解进度] [初始化] 开始生成初始解... (迭代次数: 600) (4m14s)
#
#   [求解进度] [选择最优初始解] 成本: 87606.91 (4m14s)
#
#   [求解进度] [参数] 初始温度: 8760.69, 冷却系数: 0.993501, 迭代次数: 600 (4m14s)
#
#   [求解进度] [迭代   0] ✓ 新最优解! 成本: 76027.03, 路径数: 26 (4m15s)
#
#   [求解进度] [迭代   1] ✓ 新最优解! 成本: 62795.30, 路径数: 28 (4m15s)
#
#   [求解进度] [迭代   2] ✓ 新最优解! 成本: 60438.74, 路径数: 27 (4m15s)
#
#   [求解进度] [迭代   3] ✓ 新最优解! 成本: 56916.27, 路径数: 28 (4m15s)
#
#   [求解进度] [迭代   4] ✓ 新最优解! 成本: 56185.48, 路径数: 28 (4m16s)
#   [求解进度] [████████████████████] 100.0% | 轮次3/3 迭代600/600 | 最优: 43030.18 | 已用: 6m39s | 剩余: 0s
#   [求解进度] 【最终结果】最优成本: 43030.18 (6m39s)
#
#   [求解进度] 【最终结果】路径数量: 33 (6m39s)
#
#   [求解进度] 【最终结果】改进次数: 33 (6m39s)
#
#   [求解进度] 【最终结果】最后改进: 第 561 次迭代 (6m39s)
#
#   [求解进度] 【多次运行汇总】 (6m39s)
#
#   [求解进度] 最优成本: 42412.45 (6m39s)
#
#   [求解进度] BEST_COST: 42412.45404635006 (6m39s)
#
# [执行完成] 耗时: 399.8s, 返回码: 0
# Python code executed successfully.
#
# [Solver Status] Algorithm execution completed
#
# ================================================================================
# SOLUTION SUMMARY
# ================================================================================
#
# Objective Value: 42412.45
# [调试] 开始提取路线信息...
# [调试] 格式1匹配到 0 条路线
# [调试] 尝试格式2...
# [调试] 格式2提取到 34 条路线
# [调试] 最终提取到 34 条路线
#
# [调试] 提取到的路线数量: 34
# [调试] 第一条路线示例: [0, 29, 30, 49, 0]
# [可视化] 正在生成图表...
# [可视化] 图表已保存到: d:\pythonProject\or_llm_agent\vrp_result.png
# [可视化] 矢量图已保存到: d:\pythonProject\or_llm_agent\vrp_result.pdf
#
# ================================================================================
# DETAILED OUTPUT
# ================================================================================
# [Initialization] Plugin initialized
# Solver 初始化成功
# [Initialization] Solver initialized
#
# ############################################################
# # 第 1/3 次运行
# ############################################################
# [初始化] 开始生成初始解... (迭代次数: 600)
#   [初始解尝试 1/3] 成本: 98080.76, 路径数: 20
#   [初始解尝试 2/3] 成本: 87606.91, 路径数: 21
#   [初始解尝试 3/3] 成本: 92002.45, 路径数: 20
#   [选择最优初始解] 成本: 87606.91
#
# [初始解] 成本: 87606.91
# [初始解] 路径数: 21
# [初始解] 可行性: ✓
#
# [ALNS] 开始迭代优化...
#
# [参数] 初始温度: 8760.69, 冷却系数: 0.993501, 迭代次数: 600
# [迭代   3] ✓ 新最优解! 成本: 80898.69, 路径数: 24
# [迭代   4] ✓ 新最优解! 成本: 70269.36, 路径数: 25
# Iter   5: Current=70269.36, Best=70269.36, Temp=8479.70, Routes=25
# [迭代   5] ✓ 新最优解! 成本: 64807.26, 路径数: 26
# [迭代   6] ✓ 新最优解! 成本: 59291.84, 路径数: 27
# [迭代   7] ✓ 新最优解! 成本: 55062.50, 路径数: 29
# [迭代   8] ✓ 新最优解! 成本: 50651.32, 路径数: 31
# [迭代   9] ✓ 新最优解! 成本: 49059.10, 路径数: 32
# Iter  10: Current=49059.10, Best=49059.10, Temp=8207.71, Routes=32
# [迭代  10] ✓ 新最优解! 成本: 47787.56, 路径数: 32
# [迭代  11] ✓ 新最优解! 成本: 47038.91, 路径数: 32
# [迭代  12] ✓ 新最优解! 成本: 45829.48, 路径数: 33
# [迭代  13] ✓ 新最优解! 成本: 45426.88, 路径数: 32
# [迭代  14] ✓ 新最优解! 成本: 45132.87, 路径数: 33
# Iter  15: Current=45132.87, Best=45132.87, Temp=7944.46, Routes=33
# [迭代  15] ✓ 新最优解! 成本: 45122.02, 路径数: 33
# [迭代  16] ✓ 新最优解! 成本: 44640.99, 路径数: 33
# [迭代  17] ✓ 新最优解! 成本: 44576.02, 路径数: 33
# [迭代  19] ✓ 新最优解! 成本: 44389.88, 路径数: 33
# Iter  20: Current=44389.88, Best=44389.88, Temp=7689.64, Routes=33
# [迭代  21] ✓ 新最优解! 成本: 44247.93, 路径数: 34
# [迭代  22] ✓ 新最优解! 成本: 43925.46, 路径数: 34
# [迭代  24] ✓ 新最优解! 成本: 43873.56, 路径数: 34
# Iter  25: Current=43873.56, Best=43873.56, Temp=7443.00, Routes=34
# [迭代  26] ✓ 新最优解! 成本: 43843.60, 路径数: 33
# [迭代  28] ✓ 新最优解! 成本: 43797.07, 路径数: 33
# Iter  30: Current=44078.19, Best=43797.07, Temp=7204.27, Routes=34
# Iter  35: Current=44679.47, Best=43797.07, Temp=6973.19, Routes=34
# Iter  40: Current=45591.27, Best=43797.07, Temp=6749.53, Routes=32
# Iter  45: Current=44556.56, Best=43797.07, Temp=6533.04, Routes=32
# Iter  50: Current=44007.90, Best=43797.07, Temp=6323.50, Routes=32
# Iter  55: Current=44132.64, Best=43797.07, Temp=6120.68, Routes=33
# Iter  60: Current=44319.48, Best=43797.07, Temp=5924.36, Routes=32
# Iter  65: Current=46437.84, Best=43797.07, Temp=5734.34, Routes=30
# Iter  70: Current=47004.25, Best=43797.07, Temp=5550.41, Routes=30
# Iter  75: Current=46507.54, Best=43797.07, Temp=5372.39, Routes=31
# Iter  80: Current=45776.72, Best=43797.07, Temp=5200.07, Routes=30
# Iter  85: Current=45459.37, Best=43797.07, Temp=5033.28, Routes=30
# Iter  90: Current=46537.37, Best=43797.07, Temp=4871.84, Routes=31
# Iter  95: Current=46148.31, Best=43797.07, Temp=4715.58, Routes=32
# Iter 100: Current=45585.02, Best=43797.07, Temp=4564.33, Routes=31
# Iter 105: Current=46428.91, Best=43797.07, Temp=4417.93, Routes=32
# Iter 110: Current=45718.39, Best=43797.07, Temp=4276.23, Routes=32
# Iter 115: Current=45464.13, Best=43797.07, Temp=4139.07, Routes=33
# Iter 120: Current=46191.67, Best=43797.07, Temp=4006.31, Routes=31
# Iter 125: Current=47769.28, Best=43797.07, Temp=3877.81, Routes=31
# Iter 130: Current=47258.72, Best=43797.07, Temp=3753.43, Routes=33
# Iter 135: Current=46902.41, Best=43797.07, Temp=3633.04, Routes=32
# Iter 140: Current=47519.63, Best=43797.07, Temp=3516.51, Routes=30
# Iter 145: Current=46540.30, Best=43797.07, Temp=3403.72, Routes=32
# Iter 150: Current=46809.63, Best=43797.07, Temp=3294.55, Routes=32
# Iter 155: Current=47655.21, Best=43797.07, Temp=3188.88, Routes=32
# Iter 160: Current=46455.98, Best=43797.07, Temp=3086.60, Routes=31
# Iter 165: Current=46115.27, Best=43797.07, Temp=2987.59, Routes=32
# Iter 170: Current=46582.91, Best=43797.07, Temp=2891.77, Routes=32
# Iter 175: Current=45425.17, Best=43797.07, Temp=2799.02, Routes=32
# Iter 180: Current=46095.51, Best=43797.07, Temp=2709.24, Routes=33
# Iter 185: Current=45840.25, Best=43797.07, Temp=2622.34, Routes=31
# Iter 190: Current=46379.90, Best=43797.07, Temp=2538.23, Routes=33
# Iter 195: Current=45888.86, Best=43797.07, Temp=2456.82, Routes=31
# Iter 200: Current=46398.23, Best=43797.07, Temp=2378.02, Routes=32
# Iter 205: Current=46937.99, Best=43797.07, Temp=2301.74, Routes=32
# Iter 210: Current=47044.26, Best=43797.07, Temp=2227.92, Routes=32
# Iter 215: Current=46753.13, Best=43797.07, Temp=2156.46, Routes=32
# Iter 220: Current=46095.99, Best=43797.07, Temp=2087.29, Routes=33
# Iter 225: Current=47853.54, Best=43797.07, Temp=2020.34, Routes=32
# Iter 230: Current=46227.73, Best=43797.07, Temp=1955.54, Routes=34
# Iter 235: Current=46404.90, Best=43797.07, Temp=1892.82, Routes=33
# Iter 240: Current=46061.82, Best=43797.07, Temp=1832.11, Routes=32
# Iter 245: Current=47928.01, Best=43797.07, Temp=1773.34, Routes=32
# Iter 250: Current=47432.15, Best=43797.07, Temp=1716.46, Routes=32
# Iter 255: Current=47276.66, Best=43797.07, Temp=1661.41, Routes=32
# Iter 260: Current=46481.02, Best=43797.07, Temp=1608.12, Routes=34
# Iter 265: Current=46821.55, Best=43797.07, Temp=1556.54, Routes=31
# Iter 270: Current=46874.38, Best=43797.07, Temp=1506.61, Routes=31
# Iter 275: Current=46765.50, Best=43797.07, Temp=1458.29, Routes=32
# Iter 280: Current=46807.96, Best=43797.07, Temp=1411.52, Routes=32
# Iter 285: Current=46247.99, Best=43797.07, Temp=1366.24, Routes=32
# Iter 290: Current=46809.68, Best=43797.07, Temp=1322.42, Routes=30
# Iter 295: Current=45201.72, Best=43797.07, Temp=1280.00, Routes=32
# Iter 300: Current=45474.51, Best=43797.07, Temp=1238.95, Routes=31
# Iter 305: Current=45777.77, Best=43797.07, Temp=1199.21, Routes=32
# Iter 310: Current=45759.74, Best=43797.07, Temp=1160.75, Routes=32
# Iter 315: Current=44545.19, Best=43797.07, Temp=1123.52, Routes=32
# Iter 320: Current=44471.87, Best=43797.07, Temp=1087.48, Routes=33
# Iter 325: Current=44962.78, Best=43797.07, Temp=1052.60, Routes=34
# Iter 330: Current=46689.29, Best=43797.07, Temp=1018.84, Routes=31
# Iter 335: Current=48266.11, Best=43797.07, Temp=986.16, Routes=31
# Iter 340: Current=46550.15, Best=43797.07, Temp=954.53, Routes=32
# Iter 345: Current=46876.35, Best=43797.07, Temp=923.91, Routes=31
# Iter 350: Current=45832.60, Best=43797.07, Temp=894.28, Routes=32
# Iter 355: Current=45826.14, Best=43797.07, Temp=865.59, Routes=32
# Iter 360: Current=45708.76, Best=43797.07, Temp=837.83, Routes=31
# Iter 365: Current=45507.98, Best=43797.07, Temp=810.96, Routes=32
# Iter 370: Current=45202.11, Best=43797.07, Temp=784.95, Routes=33
# Iter 375: Current=45568.77, Best=43797.07, Temp=759.77, Routes=33
# Iter 380: Current=45955.13, Best=43797.07, Temp=735.40, Routes=31
# Iter 385: Current=45253.98, Best=43797.07, Temp=711.81, Routes=33
# Iter 390: Current=44393.28, Best=43797.07, Temp=688.98, Routes=32
# Iter 395: Current=44640.28, Best=43797.07, Temp=666.88, Routes=34
# Iter 400: Current=45632.99, Best=43797.07, Temp=645.49, Routes=35
# Iter 405: Current=44648.29, Best=43797.07, Temp=624.79, Routes=34
# Iter 410: Current=44457.84, Best=43797.07, Temp=604.75, Routes=34
# Iter 415: Current=44478.28, Best=43797.07, Temp=585.35, Routes=32
# Iter 420: Current=44510.56, Best=43797.07, Temp=566.58, Routes=32
# Iter 425: Current=44551.79, Best=43797.07, Temp=548.40, Routes=34
# Iter 430: Current=45290.91, Best=43797.07, Temp=530.82, Routes=31
# Iter 435: Current=45209.90, Best=43797.07, Temp=513.79, Routes=31
# Iter 440: Current=45675.82, Best=43797.07, Temp=497.31, Routes=32
# Iter 445: Current=45324.40, Best=43797.07, Temp=481.36, Routes=33
# Iter 450: Current=44929.37, Best=43797.07, Temp=465.92, Routes=33
# Iter 455: Current=45763.51, Best=43797.07, Temp=450.98, Routes=31
# Iter 460: Current=46713.41, Best=43797.07, Temp=436.51, Routes=31
# Iter 465: Current=45794.42, Best=43797.07, Temp=422.51, Routes=32
# Iter 470: Current=45787.05, Best=43797.07, Temp=408.96, Routes=32
# Iter 475: Current=44984.82, Best=43797.07, Temp=395.84, Routes=33
# Iter 480: Current=44455.90, Best=43797.07, Temp=383.14, Routes=33
# Iter 485: Current=44354.46, Best=43797.07, Temp=370.86, Routes=33
# [迭代 487] ✓ 新最优解! 成本: 43670.59, 路径数: 33
# Iter 490: Current=43995.32, Best=43670.59, Temp=358.96, Routes=32
# Iter 495: Current=44424.98, Best=43670.59, Temp=347.45, Routes=32
# Iter 500: Current=44371.29, Best=43670.59, Temp=336.30, Routes=32
# Iter 505: Current=44346.34, Best=43670.59, Temp=325.52, Routes=33
# Iter 510: Current=43770.79, Best=43670.59, Temp=315.07, Routes=34
# [迭代 514] ✓ 新最优解! 成本: 43470.70, 路径数: 34
# Iter 515: Current=43470.70, Best=43470.70, Temp=304.97, Routes=34
# [迭代 516] ✓ 新最优解! 成本: 43438.66, 路径数: 34
# [迭代 517] ✓ 新最优解! 成本: 43405.53, 路径数: 34
# Iter 520: Current=43436.69, Best=43405.53, Temp=295.19, Routes=35
# Iter 525: Current=43436.69, Best=43405.53, Temp=285.72, Routes=35
# [迭代 525] ✓ 新最优解! 成本: 43321.83, 路径数: 35
# [迭代 527] ✓ 新最优解! 成本: 43265.02, 路径数: 35
# Iter 530: Current=43313.60, Best=43265.02, Temp=276.56, Routes=35
# [迭代 534] ✓ 新最优解! 成本: 43159.22, 路径数: 35
# Iter 535: Current=43159.22, Best=43159.22, Temp=267.68, Routes=35
# [迭代 535] ✓ 新最优解! 成本: 43156.30, 路径数: 34
# [迭代 536] ✓ 新最优解! 成本: 42591.53, 路径数: 34
# [迭代 538] ✓ 新最优解! 成本: 42412.45, 路径数: 34
# Iter 540: Current=42412.45, Best=42412.45, Temp=259.10, Routes=34
# Iter 545: Current=42467.21, Best=42412.45, Temp=250.79, Routes=33
# Iter 550: Current=42692.04, Best=42412.45, Temp=242.74, Routes=33
# Iter 555: Current=42740.08, Best=42412.45, Temp=234.96, Routes=34
# Iter 560: Current=42696.20, Best=42412.45, Temp=227.42, Routes=34
# Iter 565: Current=43098.72, Best=42412.45, Temp=220.13, Routes=32
# Iter 570: Current=43093.72, Best=42412.45, Temp=213.07, Routes=32
# Iter 575: Current=43413.94, Best=42412.45, Temp=206.23, Routes=32
# Iter 580: Current=43441.83, Best=42412.45, Temp=199.62, Routes=32
# Iter 585: Current=43441.83, Best=42412.45, Temp=193.22, Routes=32
# Iter 590: Current=43189.47, Best=42412.45, Temp=187.02, Routes=33
# Iter 595: Current=43026.44, Best=42412.45, Temp=181.02, Routes=34
# Iter 600: Current=42773.64, Best=42412.45, Temp=175.21, Routes=32
#
# ============================================================
# 【最终结果】最优成本: 42412.45
# 【最终结果】路径数量: 34
# 【最终结果】改进次数: 31
# 【最终结果】最后改进: 第 538 次迭代
# ============================================================
#
# *** 发现更优解: 42412.45 ***
#
# ############################################################
# # 第 2/3 次运行
# ############################################################
# [初始化] 开始生成初始解... (迭代次数: 600)
#   [初始解尝试 1/3] 成本: 98080.76, 路径数: 20
#   [初始解尝试 2/3] 成本: 87606.91, 路径数: 21
#   [初始解尝试 3/3] 成本: 98838.00, 路径数: 19
#   [选择最优初始解] 成本: 87606.91
#
# [初始解] 成本: 87606.91
# [初始解] 路径数: 21
# [初始解] 可行性: ✓
#
# [ALNS] 开始迭代优化...
#
# [参数] 初始温度: 8760.69, 冷却系数: 0.993501, 迭代次数: 600
# [迭代   0] ✓ 新最优解! 成本: 74986.80, 路径数: 23
# [迭代   1] ✓ 新最优解! 成本: 65360.22, 路径数: 25
# [迭代   2] ✓ 新最优解! 成本: 61095.51, 路径数: 27
# [迭代   3] ✓ 新最优解! 成本: 58070.00, 路径数: 29
# [迭代   4] ✓ 新最优解! 成本: 51648.99, 路径数: 31
# Iter   5: Current=51648.99, Best=51648.99, Temp=8479.70, Routes=31
# [迭代   5] ✓ 新最优解! 成本: 50350.18, 路径数: 31
# [迭代   6] ✓ 新最优解! 成本: 49691.52, 路径数: 31
# [迭代   7] ✓ 新最优解! 成本: 49625.48, 路径数: 31
# [迭代   9] ✓ 新最优解! 成本: 49275.35, 路径数: 31
# Iter  10: Current=49275.35, Best=49275.35, Temp=8207.71, Routes=31
# [迭代  11] ✓ 新最优解! 成本: 49148.38, 路径数: 32
# [迭代  12] ✓ 新最优解! 成本: 47744.36, 路径数: 32
# [迭代  13] ✓ 新最优解! 成本: 47714.91, 路径数: 32
# [迭代  14] ✓ 新最优解! 成本: 47611.40, 路径数: 32
# Iter  15: Current=47611.40, Best=47611.40, Temp=7944.46, Routes=32
# [迭代  15] ✓ 新最优解! 成本: 46965.52, 路径数: 33
# [迭代  16] ✓ 新最优解! 成本: 46271.61, 路径数: 33
# [迭代  18] ✓ 新最优解! 成本: 46214.80, 路径数: 33
# [迭代  19] ✓ 新最优解! 成本: 45935.03, 路径数: 33
# Iter  20: Current=45935.03, Best=45935.03, Temp=7689.64, Routes=33
# [迭代  20] ✓ 新最优解! 成本: 45934.27, 路径数: 33
# [迭代  21] ✓ 新最优解! 成本: 45758.61, 路径数: 32
# [迭代  22] ✓ 新最优解! 成本: 45682.65, 路径数: 32
# [迭代  23] ✓ 新最优解! 成本: 45510.39, 路径数: 33
# Iter  25: Current=45674.00, Best=45510.39, Temp=7443.00, Routes=33
# [迭代  27] ✓ 新最优解! 成本: 45504.64, 路径数: 34
# [迭代  28] ✓ 新最优解! 成本: 45450.54, 路径数: 34
# Iter  30: Current=45586.42, Best=45450.54, Temp=7204.27, Routes=33
# [迭代  32] ✓ 新最优解! 成本: 45189.35, 路径数: 33
# [迭代  33] ✓ 新最优解! 成本: 44819.28, 路径数: 33
# Iter  35: Current=45283.78, Best=44819.28, Temp=6973.19, Routes=32
# [迭代  37] ✓ 新最优解! 成本: 44687.78, 路径数: 33
# Iter  40: Current=44913.16, Best=44687.78, Temp=6749.53, Routes=31
# [迭代  42] ✓ 新最优解! 成本: 44284.37, 路径数: 33
# Iter  45: Current=44518.49, Best=44284.37, Temp=6533.04, Routes=34
# [迭代  49] ✓ 新最优解! 成本: 44018.18, 路径数: 35
# Iter  50: Current=44018.18, Best=44018.18, Temp=6323.50, Routes=35
# [迭代  53] ✓ 新最优解! 成本: 43960.20, 路径数: 32
# Iter  55: Current=44431.38, Best=43960.20, Temp=6120.68, Routes=31
# Iter  60: Current=45194.44, Best=43960.20, Temp=5924.36, Routes=33
# Iter  65: Current=44376.26, Best=43960.20, Temp=5734.34, Routes=34
# [迭代  69] ✓ 新最优解! 成本: 43774.79, 路径数: 33
# Iter  70: Current=43774.79, Best=43774.79, Temp=5550.41, Routes=33
# [迭代  70] ✓ 新最优解! 成本: 43740.08, 路径数: 33
# Iter  75: Current=43974.04, Best=43740.08, Temp=5372.39, Routes=34
# [迭代  75] ✓ 新最优解! 成本: 43481.96, 路径数: 34
# [迭代  78] ✓ 新最优解! 成本: 43311.22, 路径数: 35
# [迭代  79] ✓ 新最优解! 成本: 43267.14, 路径数: 34
# Iter  80: Current=43267.14, Best=43267.14, Temp=5200.07, Routes=34
# [迭代  80] ✓ 新最优解! 成本: 43249.98, 路径数: 34
# Iter  85: Current=43734.49, Best=43249.98, Temp=5033.28, Routes=36
# Iter  90: Current=43633.05, Best=43249.98, Temp=4871.84, Routes=34
# Iter  95: Current=44211.29, Best=43249.98, Temp=4715.58, Routes=32
# Iter 100: Current=45343.58, Best=43249.98, Temp=4564.33, Routes=32
# Iter 105: Current=45484.15, Best=43249.98, Temp=4417.93, Routes=35
# Iter 110: Current=45092.96, Best=43249.98, Temp=4276.23, Routes=34
# Iter 115: Current=45129.45, Best=43249.98, Temp=4139.07, Routes=33
# Iter 120: Current=45185.48, Best=43249.98, Temp=4006.31, Routes=33
# Iter 125: Current=45088.27, Best=43249.98, Temp=3877.81, Routes=33
# Iter 130: Current=44747.33, Best=43249.98, Temp=3753.43, Routes=33
# Iter 135: Current=44290.37, Best=43249.98, Temp=3633.04, Routes=34
# Iter 140: Current=45301.11, Best=43249.98, Temp=3516.51, Routes=33
# Iter 145: Current=45743.66, Best=43249.98, Temp=3403.72, Routes=32
# Iter 150: Current=45539.10, Best=43249.98, Temp=3294.55, Routes=32
# Iter 155: Current=46339.40, Best=43249.98, Temp=3188.88, Routes=32
# Iter 160: Current=45774.22, Best=43249.98, Temp=3086.60, Routes=32
# Iter 165: Current=45477.62, Best=43249.98, Temp=2987.59, Routes=34
# Iter 170: Current=44998.93, Best=43249.98, Temp=2891.77, Routes=34
# Iter 175: Current=44627.56, Best=43249.98, Temp=2799.02, Routes=34
# Iter 180: Current=44954.41, Best=43249.98, Temp=2709.24, Routes=33
# Iter 185: Current=45718.00, Best=43249.98, Temp=2622.34, Routes=31
# Iter 190: Current=44402.45, Best=43249.98, Temp=2538.23, Routes=31
# Iter 195: Current=45720.71, Best=43249.98, Temp=2456.82, Routes=32
# Iter 200: Current=45759.35, Best=43249.98, Temp=2378.02, Routes=34
# Iter 205: Current=44554.97, Best=43249.98, Temp=2301.74, Routes=32
# Iter 210: Current=44859.24, Best=43249.98, Temp=2227.92, Routes=34
# Iter 215: Current=45521.70, Best=43249.98, Temp=2156.46, Routes=33
# Iter 220: Current=45472.81, Best=43249.98, Temp=2087.29, Routes=32
# Iter 225: Current=44961.35, Best=43249.98, Temp=2020.34, Routes=32
# Iter 230: Current=45092.11, Best=43249.98, Temp=1955.54, Routes=31
# Iter 235: Current=46732.54, Best=43249.98, Temp=1892.82, Routes=32
# Iter 240: Current=47155.77, Best=43249.98, Temp=1832.11, Routes=32
# Iter 245: Current=45657.87, Best=43249.98, Temp=1773.34, Routes=33
# Iter 250: Current=45430.69, Best=43249.98, Temp=1716.46, Routes=32
# Iter 255: Current=45419.49, Best=43249.98, Temp=1661.41, Routes=32
# Iter 260: Current=47207.64, Best=43249.98, Temp=1608.12, Routes=33
# Iter 265: Current=47795.94, Best=43249.98, Temp=1556.54, Routes=35
# Iter 270: Current=47118.81, Best=43249.98, Temp=1506.61, Routes=34
# Iter 275: Current=47427.27, Best=43249.98, Temp=1458.29, Routes=34
# Iter 280: Current=46882.44, Best=43249.98, Temp=1411.52, Routes=33
# Iter 285: Current=47963.17, Best=43249.98, Temp=1366.24, Routes=29
# Iter 290: Current=46410.18, Best=43249.98, Temp=1322.42, Routes=31
# Iter 295: Current=45907.46, Best=43249.98, Temp=1280.00, Routes=32
# Iter 300: Current=46810.34, Best=43249.98, Temp=1238.95, Routes=32
# Iter 305: Current=46164.76, Best=43249.98, Temp=1199.21, Routes=34
# Iter 310: Current=47943.26, Best=43249.98, Temp=1160.75, Routes=31
# Iter 315: Current=46892.10, Best=43249.98, Temp=1123.52, Routes=32
# Iter 320: Current=45979.05, Best=43249.98, Temp=1087.48, Routes=32
# Iter 325: Current=45684.00, Best=43249.98, Temp=1052.60, Routes=34
# Iter 330: Current=46630.01, Best=43249.98, Temp=1018.84, Routes=35
# Iter 335: Current=45263.10, Best=43249.98, Temp=986.16, Routes=35
# Iter 340: Current=46020.59, Best=43249.98, Temp=954.53, Routes=34
# Iter 345: Current=45031.21, Best=43249.98, Temp=923.91, Routes=34
# Iter 350: Current=44933.44, Best=43249.98, Temp=894.28, Routes=32
# Iter 355: Current=46547.43, Best=43249.98, Temp=865.59, Routes=32
# Iter 360: Current=46768.90, Best=43249.98, Temp=837.83, Routes=33
# Iter 365: Current=46360.65, Best=43249.98, Temp=810.96, Routes=32
# Iter 370: Current=45716.09, Best=43249.98, Temp=784.95, Routes=33
# Iter 375: Current=46670.60, Best=43249.98, Temp=759.77, Routes=32
# Iter 380: Current=46737.32, Best=43249.98, Temp=735.40, Routes=32
# Iter 385: Current=45967.41, Best=43249.98, Temp=711.81, Routes=34
# Iter 390: Current=45324.81, Best=43249.98, Temp=688.98, Routes=32
# Iter 395: Current=46171.86, Best=43249.98, Temp=666.88, Routes=33
# Iter 400: Current=45862.12, Best=43249.98, Temp=645.49, Routes=35
# Iter 405: Current=45724.52, Best=43249.98, Temp=624.79, Routes=35
# Iter 410: Current=46067.16, Best=43249.98, Temp=604.75, Routes=36
# Iter 415: Current=45579.93, Best=43249.98, Temp=585.35, Routes=36
# Iter 420: Current=45250.66, Best=43249.98, Temp=566.58, Routes=34
# Iter 425: Current=45408.17, Best=43249.98, Temp=548.40, Routes=33
# Iter 430: Current=44977.12, Best=43249.98, Temp=530.82, Routes=34
# Iter 435: Current=45253.81, Best=43249.98, Temp=513.79, Routes=35
# Iter 440: Current=45445.43, Best=43249.98, Temp=497.31, Routes=35
# Iter 445: Current=44789.29, Best=43249.98, Temp=481.36, Routes=35
# Iter 450: Current=44645.77, Best=43249.98, Temp=465.92, Routes=33
# Iter 455: Current=45465.93, Best=43249.98, Temp=450.98, Routes=32
# Iter 460: Current=45251.81, Best=43249.98, Temp=436.51, Routes=33
# Iter 465: Current=45547.18, Best=43249.98, Temp=422.51, Routes=32
# Iter 470: Current=44894.98, Best=43249.98, Temp=408.96, Routes=34
# Iter 475: Current=44587.83, Best=43249.98, Temp=395.84, Routes=34
# Iter 480: Current=44494.27, Best=43249.98, Temp=383.14, Routes=34
# Iter 485: Current=44777.59, Best=43249.98, Temp=370.86, Routes=35
# Iter 490: Current=44624.22, Best=43249.98, Temp=358.96, Routes=36
# Iter 495: Current=44391.65, Best=43249.98, Temp=347.45, Routes=35
# Iter 500: Current=44296.81, Best=43249.98, Temp=336.30, Routes=34
# Iter 505: Current=44257.63, Best=43249.98, Temp=325.52, Routes=34
# Iter 510: Current=44645.04, Best=43249.98, Temp=315.07, Routes=33
# Iter 515: Current=44757.01, Best=43249.98, Temp=304.97, Routes=33
# Iter 520: Current=43784.02, Best=43249.98, Temp=295.19, Routes=34
# Iter 525: Current=43749.04, Best=43249.98, Temp=285.72, Routes=34
# Iter 530: Current=43975.49, Best=43249.98, Temp=276.56, Routes=33
# Iter 535: Current=43958.91, Best=43249.98, Temp=267.68, Routes=32
# Iter 540: Current=43815.44, Best=43249.98, Temp=259.10, Routes=33
# Iter 545: Current=43717.15, Best=43249.98, Temp=250.79, Routes=33
# Iter 550: Current=43944.83, Best=43249.98, Temp=242.74, Routes=33
# Iter 555: Current=43657.85, Best=43249.98, Temp=234.96, Routes=33
# [迭代 558] ✓ 新最优解! 成本: 43193.48, 路径数: 32
# Iter 560: Current=43251.55, Best=43193.48, Temp=227.42, Routes=32
# Iter 565: Current=43208.99, Best=43193.48, Temp=220.13, Routes=32
# [迭代 567] ✓ 新最优解! 成本: 43182.78, 路径数: 32
# Iter 570: Current=43182.78, Best=43182.78, Temp=213.07, Routes=32
# [迭代 574] ✓ 新最优解! 成本: 42826.60, 路径数: 33
# Iter 575: Current=42826.60, Best=42826.60, Temp=206.23, Routes=33
# [迭代 576] ✓ 新最优解! 成本: 42764.11, 路径数: 33
# Iter 580: Current=43043.56, Best=42764.11, Temp=199.62, Routes=34
# Iter 585: Current=42890.82, Best=42764.11, Temp=193.22, Routes=33
# Iter 590: Current=42909.64, Best=42764.11, Temp=187.02, Routes=33
# Iter 595: Current=42948.67, Best=42764.11, Temp=181.02, Routes=33
# Iter 600: Current=42984.55, Best=42764.11, Temp=175.21, Routes=33
#
# ============================================================
# 【最终结果】最优成本: 42764.11
# 【最终结果】路径数量: 33
# 【最终结果】改进次数: 39
# 【最终结果】最后改进: 第 576 次迭代
# ============================================================
#
#
# ############################################################
# # 第 3/3 次运行
# ############################################################
# [初始化] 开始生成初始解... (迭代次数: 600)
#   [初始解尝试 1/3] 成本: 98080.76, 路径数: 20
#   [初始解尝试 2/3] 成本: 87606.91, 路径数: 21
#   [初始解尝试 3/3] 成本: 98080.76, 路径数: 20
#   [选择最优初始解] 成本: 87606.91
#
# [初始解] 成本: 87606.91
# [初始解] 路径数: 21
# [初始解] 可行性: ✓
#
# [ALNS] 开始迭代优化...
#
# [参数] 初始温度: 8760.69, 冷却系数: 0.993501, 迭代次数: 600
# [迭代   0] ✓ 新最优解! 成本: 76027.03, 路径数: 26
# [迭代   1] ✓ 新最优解! 成本: 62795.30, 路径数: 28
# [迭代   2] ✓ 新最优解! 成本: 60438.74, 路径数: 27
# [迭代   3] ✓ 新最优解! 成本: 56916.27, 路径数: 28
# [迭代   4] ✓ 新最优解! 成本: 56185.48, 路径数: 28
# Iter   5: Current=56185.48, Best=56185.48, Temp=8479.70, Routes=28
# [迭代   5] ✓ 新最优解! 成本: 53345.45, 路径数: 29
# [迭代   6] ✓ 新最优解! 成本: 50939.95, 路径数: 29
# [迭代   7] ✓ 新最优解! 成本: 50132.95, 路径数: 30
# [迭代   8] ✓ 新最优解! 成本: 49908.68, 路径数: 29
# [迭代   9] ✓ 新最优解! 成本: 49659.06, 路径数: 30
# Iter  10: Current=49659.06, Best=49659.06, Temp=8207.71, Routes=30
# [迭代  10] ✓ 新最优解! 成本: 46909.38, 路径数: 32
# [迭代  11] ✓ 新最优解! 成本: 46825.93, 路径数: 32
# [迭代  12] ✓ 新最优解! 成本: 46270.78, 路径数: 32
# [迭代  13] ✓ 新最优解! 成本: 46194.77, 路径数: 33
# [迭代  14] ✓ 新最优解! 成本: 45763.31, 路径数: 32
# Iter  15: Current=45763.31, Best=45763.31, Temp=7944.46, Routes=32
# [迭代  15] ✓ 新最优解! 成本: 45441.50, 路径数: 31
# Iter  20: Current=45912.95, Best=45441.50, Temp=7689.64, Routes=33
# [迭代  20] ✓ 新最优解! 成本: 44949.60, 路径数: 33
# Iter  25: Current=45781.28, Best=44949.60, Temp=7443.00, Routes=32
# Iter  30: Current=45024.40, Best=44949.60, Temp=7204.27, Routes=33
# [迭代  31] ✓ 新最优解! 成本: 44874.55, 路径数: 33
# [迭代  34] ✓ 新最优解! 成本: 44572.40, 路径数: 33
# Iter  35: Current=44572.40, Best=44572.40, Temp=6973.19, Routes=33
# Iter  40: Current=45268.90, Best=44572.40, Temp=6749.53, Routes=33
# Iter  45: Current=45428.93, Best=44572.40, Temp=6533.04, Routes=33
# Iter  50: Current=44817.85, Best=44572.40, Temp=6323.50, Routes=32
# Iter  55: Current=45694.62, Best=44572.40, Temp=6120.68, Routes=32
# Iter  60: Current=45679.35, Best=44572.40, Temp=5924.36, Routes=33
# Iter  65: Current=44733.08, Best=44572.40, Temp=5734.34, Routes=33
# Iter  70: Current=45737.90, Best=44572.40, Temp=5550.41, Routes=34
# Iter  75: Current=45467.02, Best=44572.40, Temp=5372.39, Routes=34
# Iter  80: Current=45522.61, Best=44572.40, Temp=5200.07, Routes=36
# Iter  85: Current=45490.18, Best=44572.40, Temp=5033.28, Routes=35
# Iter  90: Current=45285.37, Best=44572.40, Temp=4871.84, Routes=35
# Iter  95: Current=45489.06, Best=44572.40, Temp=4715.58, Routes=34
# Iter 100: Current=46827.65, Best=44572.40, Temp=4564.33, Routes=32
# Iter 105: Current=47848.35, Best=44572.40, Temp=4417.93, Routes=31
# Iter 110: Current=47909.92, Best=44572.40, Temp=4276.23, Routes=35
# Iter 115: Current=47316.04, Best=44572.40, Temp=4139.07, Routes=33
# Iter 120: Current=49736.05, Best=44572.40, Temp=4006.31, Routes=31
# Iter 125: Current=48870.70, Best=44572.40, Temp=3877.81, Routes=30
# Iter 130: Current=48549.74, Best=44572.40, Temp=3753.43, Routes=32
# Iter 135: Current=46774.69, Best=44572.40, Temp=3633.04, Routes=32
# Iter 140: Current=46204.61, Best=44572.40, Temp=3516.51, Routes=32
# Iter 145: Current=45583.66, Best=44572.40, Temp=3403.72, Routes=32
# Iter 150: Current=46485.01, Best=44572.40, Temp=3294.55, Routes=32
# Iter 155: Current=45777.02, Best=44572.40, Temp=3188.88, Routes=34
# Iter 160: Current=45731.73, Best=44572.40, Temp=3086.60, Routes=33
# Iter 165: Current=45263.41, Best=44572.40, Temp=2987.59, Routes=33
# Iter 170: Current=45335.66, Best=44572.40, Temp=2891.77, Routes=32
# Iter 175: Current=45636.51, Best=44572.40, Temp=2799.02, Routes=33
# Iter 180: Current=44695.21, Best=44572.40, Temp=2709.24, Routes=34
# Iter 185: Current=44980.63, Best=44572.40, Temp=2622.34, Routes=34
# Iter 190: Current=45912.41, Best=44572.40, Temp=2538.23, Routes=33
# Iter 195: Current=45942.45, Best=44572.40, Temp=2456.82, Routes=35
# Iter 200: Current=46685.04, Best=44572.40, Temp=2378.02, Routes=33
# Iter 205: Current=46360.42, Best=44572.40, Temp=2301.74, Routes=33
# Iter 210: Current=45897.34, Best=44572.40, Temp=2227.92, Routes=33
# Iter 215: Current=45779.12, Best=44572.40, Temp=2156.46, Routes=34
# Iter 220: Current=45761.35, Best=44572.40, Temp=2087.29, Routes=32
# Iter 225: Current=46259.11, Best=44572.40, Temp=2020.34, Routes=32
# Iter 230: Current=46583.90, Best=44572.40, Temp=1955.54, Routes=32
# Iter 235: Current=45174.65, Best=44572.40, Temp=1892.82, Routes=34
# Iter 240: Current=44644.64, Best=44572.40, Temp=1832.11, Routes=35
# [迭代 244] ✓ 新最优解! 成本: 44475.85, 路径数: 34
# Iter 245: Current=44475.85, Best=44475.85, Temp=1773.34, Routes=34
# [迭代 246] ✓ 新最优解! 成本: 44106.39, 路径数: 34
# Iter 250: Current=44312.30, Best=44106.39, Temp=1716.46, Routes=33
# Iter 255: Current=44480.02, Best=44106.39, Temp=1661.41, Routes=31
# Iter 260: Current=45633.31, Best=44106.39, Temp=1608.12, Routes=33
# Iter 265: Current=45068.25, Best=44106.39, Temp=1556.54, Routes=33
# Iter 270: Current=45161.52, Best=44106.39, Temp=1506.61, Routes=33
# Iter 275: Current=45253.14, Best=44106.39, Temp=1458.29, Routes=34
# Iter 280: Current=44611.43, Best=44106.39, Temp=1411.52, Routes=33
# Iter 285: Current=46352.70, Best=44106.39, Temp=1366.24, Routes=33
# Iter 290: Current=46785.89, Best=44106.39, Temp=1322.42, Routes=32
# Iter 295: Current=48588.54, Best=44106.39, Temp=1280.00, Routes=33
# Iter 300: Current=46581.63, Best=44106.39, Temp=1238.95, Routes=33
# Iter 305: Current=46924.10, Best=44106.39, Temp=1199.21, Routes=33
# Iter 310: Current=47665.15, Best=44106.39, Temp=1160.75, Routes=30
# Iter 315: Current=46882.19, Best=44106.39, Temp=1123.52, Routes=32
# Iter 320: Current=47267.05, Best=44106.39, Temp=1087.48, Routes=33
# Iter 325: Current=47969.05, Best=44106.39, Temp=1052.60, Routes=30
# Iter 330: Current=46873.49, Best=44106.39, Temp=1018.84, Routes=31
# Iter 335: Current=47223.69, Best=44106.39, Temp=986.16, Routes=32
# Iter 340: Current=47921.29, Best=44106.39, Temp=954.53, Routes=31
# Iter 345: Current=46476.64, Best=44106.39, Temp=923.91, Routes=33
# Iter 350: Current=45842.81, Best=44106.39, Temp=894.28, Routes=34
# Iter 355: Current=45994.20, Best=44106.39, Temp=865.59, Routes=34
# Iter 360: Current=45066.88, Best=44106.39, Temp=837.83, Routes=34
# Iter 365: Current=45460.28, Best=44106.39, Temp=810.96, Routes=33
# Iter 370: Current=45092.84, Best=44106.39, Temp=784.95, Routes=31
# Iter 375: Current=44818.10, Best=44106.39, Temp=759.77, Routes=33
# Iter 380: Current=44947.30, Best=44106.39, Temp=735.40, Routes=33
# Iter 385: Current=45453.30, Best=44106.39, Temp=711.81, Routes=33
# Iter 390: Current=45871.38, Best=44106.39, Temp=688.98, Routes=33
# Iter 395: Current=45647.05, Best=44106.39, Temp=666.88, Routes=32
# Iter 400: Current=45528.93, Best=44106.39, Temp=645.49, Routes=33
# Iter 405: Current=45714.34, Best=44106.39, Temp=624.79, Routes=31
# Iter 410: Current=45033.53, Best=44106.39, Temp=604.75, Routes=32
# Iter 415: Current=45403.45, Best=44106.39, Temp=585.35, Routes=32
# Iter 420: Current=45200.55, Best=44106.39, Temp=566.58, Routes=33
# Iter 425: Current=44604.29, Best=44106.39, Temp=548.40, Routes=34
# Iter 430: Current=44425.21, Best=44106.39, Temp=530.82, Routes=32
# Iter 435: Current=44392.86, Best=44106.39, Temp=513.79, Routes=33
# Iter 440: Current=44557.90, Best=44106.39, Temp=497.31, Routes=33
# Iter 445: Current=44809.17, Best=44106.39, Temp=481.36, Routes=35
# [迭代 447] ✓ 新最优解! 成本: 43909.27, 路径数: 35
# Iter 450: Current=43909.27, Best=43909.27, Temp=465.92, Routes=35
# [迭代 450] ✓ 新最优解! 成本: 43865.96, 路径数: 34
# [迭代 451] ✓ 新最优解! 成本: 43857.21, 路径数: 33
# [迭代 453] ✓ 新最优解! 成本: 43780.22, 路径数: 33
# Iter 455: Current=43780.22, Best=43780.22, Temp=450.98, Routes=33
# Iter 460: Current=44092.60, Best=43780.22, Temp=436.51, Routes=33
# Iter 465: Current=43945.29, Best=43780.22, Temp=422.51, Routes=33
# Iter 470: Current=44662.71, Best=43780.22, Temp=408.96, Routes=33
# Iter 475: Current=44668.94, Best=43780.22, Temp=395.84, Routes=34
# Iter 480: Current=44655.97, Best=43780.22, Temp=383.14, Routes=33
# Iter 485: Current=44384.36, Best=43780.22, Temp=370.86, Routes=33
# Iter 490: Current=44014.28, Best=43780.22, Temp=358.96, Routes=32
# Iter 495: Current=44052.78, Best=43780.22, Temp=347.45, Routes=31
# Iter 500: Current=44660.95, Best=43780.22, Temp=336.30, Routes=31
# Iter 505: Current=44419.78, Best=43780.22, Temp=325.52, Routes=32
# Iter 510: Current=44322.61, Best=43780.22, Temp=315.07, Routes=30
# [迭代 511] ✓ 新最优解! 成本: 43656.72, 路径数: 32
# [迭代 512] ✓ 新最优解! 成本: 43482.99, 路径数: 32
# [迭代 514] ✓ 新最优解! 成本: 43362.47, 路径数: 33
# Iter 515: Current=43362.47, Best=43362.47, Temp=304.97, Routes=33
# [迭代 516] ✓ 新最优解! 成本: 43197.90, 路径数: 33
# Iter 520: Current=43478.09, Best=43197.90, Temp=295.19, Routes=31
# Iter 525: Current=43409.33, Best=43197.90, Temp=285.72, Routes=32
# Iter 530: Current=43574.46, Best=43197.90, Temp=276.56, Routes=33
# Iter 535: Current=43739.21, Best=43197.90, Temp=267.68, Routes=33
# Iter 540: Current=43526.09, Best=43197.90, Temp=259.10, Routes=33
# [迭代 544] ✓ 新最优解! 成本: 43109.01, 路径数: 34
# Iter 545: Current=43109.01, Best=43109.01, Temp=250.79, Routes=34
# [迭代 547] ✓ 新最优解! 成本: 43090.37, 路径数: 34
# [迭代 548] ✓ 新最优解! 成本: 43061.19, 路径数: 33
# Iter 550: Current=44356.49, Best=43061.19, Temp=242.74, Routes=33
# Iter 555: Current=43481.31, Best=43061.19, Temp=234.96, Routes=35
# Iter 560: Current=43519.22, Best=43061.19, Temp=227.42, Routes=35
# [迭代 561] ✓ 新最优解! 成本: 43030.18, 路径数: 33
# Iter 565: Current=43374.41, Best=43030.18, Temp=220.13, Routes=32
# Iter 570: Current=43745.50, Best=43030.18, Temp=213.07, Routes=32
# Iter 575: Current=43349.27, Best=43030.18, Temp=206.23, Routes=33
# Iter 580: Current=44018.05, Best=43030.18, Temp=199.62, Routes=32
# Iter 585: Current=44211.20, Best=43030.18, Temp=193.22, Routes=31
# Iter 590: Current=44497.74, Best=43030.18, Temp=187.02, Routes=31
# Iter 595: Current=44497.74, Best=43030.18, Temp=181.02, Routes=31
# Iter 600: Current=44244.60, Best=43030.18, Temp=175.21, Routes=31
#
# ============================================================
# 【最终结果】最优成本: 43030.18
# 【最终结果】路径数量: 33
# 【最终结果】改进次数: 33
# 【最终结果】最后改进: 第 561 次迭代
# ============================================================
#
#
# ============================================================
# 【多次运行汇总】
#   最优成本: 42412.45
#   平均成本: 42735.58
#   路径数量: 34
#   各次成本: ['42412.45', '42764.11', '43030.18']
# ============================================================
#
# BEST_COST: 42412.45404635006
# BEST_SOLUTION: [[0, 29, 30, 49, 0], [0, 38, 39, 36, 0], [0, 10, 93, 9, 0], [0, 45, 48, 68, 0], [0, 81, 78, 83, 0], [0, 82, 84, 91, 0], [0, 7, 8, 4, 0], [0, 46, 61, 64, 0], [0, 12, 50, 0], [0, 42, 63, 62, 44, 0], [0, 95, 94, 92, 0], [0, 58, 60, 59, 0], [0, 5, 3, 1, 0], [0, 98, 96, 75, 0], [0, 87, 86, 27, 11, 0], [0, 40, 56, 72, 0], [0, 97, 100, 99, 0], [0, 57, 54, 69, 0], [0, 20, 41, 47, 0], [0, 13, 17, 18, 0], [0, 43, 25, 34, 0], [0, 31, 35, 37, 0], [0, 90, 76, 71, 80, 0], [0, 67, 65, 2, 0], [0, 24, 55, 53, 0], [0, 28, 26, 23, 0], [0, 70, 73, 77, 0], [0, 88, 89, 0], [0, 74, 21, 0], [0, 15, 16, 14, 0], [0, 6, 51, 0], [0, 32, 33, 19, 0], [0, 22, 52, 0], [0, 85, 79, 66, 0]]
